# %% [markdown]
# We use data analytics for analyzing the data

# %%
#Import important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'D:\M.eng\Machine learning\ML_project\WaterSafety_Data.xlsx')
df = pd.DataFrame(df)

# %%
df.head(10)
# Out:
#    aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       2.40     6.82    0.660    1.87    0.100        7.56      0.47    0.33
# 1       0.03    15.84    0.020    1.31    0.060        0.19      0.02    0.06
# 2       0.01     7.10    0.170    4.34    0.020        4.81      0.38    0.86
# 3       0.08    26.78    0.010    0.87    0.000        0.45      0.02    0.75
# 4       0.08    28.19    0.001    0.25    0.001        3.58      0.68    1.29
# 5       0.01    20.34    0.030    2.31    0.006        7.97      0.53    0.07
# 6       0.08    21.95    0.050    0.36    0.090        0.48      0.10    0.05
# 7       0.02    19.16    0.020    1.18    0.020        0.46      0.06    0.78
# 8       0.07    19.13    0.100    0.35    0.080        0.58      0.00    0.29
# 9       0.15    27.45    0.030    0.74    0.002        7.07      0.52    1.69
#
#    fluoride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       aluminium  ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          2.40     6.82    0.660    1.87    0.100        7.56      0.47
# 1          0.03    15.84    0.020    1.31    0.060        0.19      0.02
# 2          0.01     7.10    0.170    4.34    0.020        4.81      0.38
# 3          0.08    26.78    0.010    0.87    0.000        0.45      0.02
# 4          0.08    28.19    0.001    0.25    0.001        3.58      0.68
# ...         ...      ...      ...     ...      ...         ...       ...
# 4791       0.08     8.75    0.020    0.99    0.000        0.06      0.08
# 4792       0.31    29.13    0.390    1.91    0.030        3.58      0.46
# 4793       0.00    24.82    0.050    0.05    0.080        0.51      0.00
# 4794       0.04     0.51    0.040    0.87    0.010        0.06      0.06
# 4795       0.08    21.01    0.050    0.03    0.080        0.45      0.09
#
# ...

# %%
#check missing data
missing_value = ['n/a','-','--','na','NaN','','#N/A','  '] 
df = pd.read_excel(r'D:\M.eng\Machine learning\ML_project\WaterSafety_Data.xlsx',na_values = missing_value)
df = pd.DataFrame(df)

# %%
df.isnull().sum()
# Out:
# aluminium      0
# ammonia        0
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# fluoride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        0
# dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'aluminium'}>,
#         <Axes: title={'center': 'ammonia'}>,
#         <Axes: title={'center': 'arsenic'}>,
#         <Axes: title={'center': 'barium'}>,
#         <Axes: title={'center': 'cadmium'}>],
#        [<Axes: title={'center': 'chloramine'}>,
#         <Axes: title={'center': 'chromium'}>,
#         <Axes: title={'center': 'copper'}>,
#         <Axes: title={'center': 'fluoride'}>,
#         <Axes: title={'center': 'bacteria'}>],
#        [<Axes: title={'center': 'viruses'}>,
#         <Axes: title={'center': 'lead'}>,
#         <Axes: title={'center': 'nitrates'}>,
#         <Axes: title={'center': 'nitrites'}>,
#         <Axes: title={'center': 'mercury'}>],
#        [<Axes: title={'center': 'perchlorate'}>,
#         <Axes: title={'center': 'radium'}>,
#         <Axes: title={'center': 'selenium'}>,
#         <Axes: title={'center': 'silver'}>,
#         <Axes: title={'center': 'uranium'}>],
# ...

# %% [markdown]
# # Boxplot

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
ax = sns.boxplot(x='is_safe', y='aluminium',data =df,color='#F7CFD8')

# %%
ax = sns.boxplot(x='is_safe', y='ammonia',data =df,color='#F4F8D3')

# %%
ax = sns.boxplot(x='is_safe', y='arsenic',data =df,color='#A6D6D6')

# %%
ax = sns.boxplot(x='is_safe', y='barium',data =df,color='#8E7DBE')

# %%
ax = sns.boxplot(x='is_safe', y='cadmium',data =df,color='#102E50')

# %%
ax = sns.boxplot(x='is_safe', y='chloramine',data =df,color='#F5C45E')

# %%
ax = sns.boxplot(x='is_safe', y='chromium',data =df,color='#E78B48')

# %%
ax = sns.boxplot(x='is_safe', y='copper',data =df,color='#BE3D2A')

# %%
ax = sns.boxplot(x='is_safe', y='fluoride',data =df,color='#F1E7E7')

# %%
ax = sns.boxplot(x='is_safe', y='bacteria',data =df,color='#E69DB8')

# %%
ax = sns.boxplot(x='is_safe', y='viruses',data =df,color='#FFD0C7')

# %%
ax = sns.boxplot(x='is_safe', y='lead',data =df,color='#FFFECE')

# %%
ax = sns.boxplot(x='is_safe', y='nitrates',data =df,color='#60B5FF')

# %%
ax = sns.boxplot(x='is_safe', y='mercury',data =df,color='#AFDDFF')

# %%
ax = sns.boxplot(x='is_safe', y='perchlorate',data =df,color='#8F87F1')

# %%
ax = sns.boxplot(x='is_safe', y='radium',data =df,color='#C68EFD')

# %%
ax = sns.boxplot(x='is_safe', y='selenium',data =df,color='#E9A5F1')

# %%
ax = sns.boxplot(x='is_safe', y='nitrites',data =df,color='#ADB2D4')

# %%
ax = sns.boxplot(x='is_safe', y='silver',data =df,color='#C7D9DD')

# %%
ax = sns.boxplot(x='is_safe', y='uranium',data =df,color='#D5E5D5')

# %%
#define the predictor variable and the response variable
x = df['ammonia']
y = df['is_safe'] #binary
sns.regplot(x=y, y=x, data=df, scatter= True,label=['safe','not safe'])
# Out:
# <Axes: xlabel='is_safe', ylabel='ammonia'>

# %%
import random as rd
#random number form max to min of selected column
select_df = df['uranium']
a = rd.randint(int(min(select_df)),int(max(select_df)))
b = rd.random()
print(f"{a+b:.4f}")
# Out:
# 0.6587

# %%
# Import necessary modules
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


# Compute correlation matrix
co_mtx = df.corr(numeric_only=True)

# Print correlation matrix
print(co_mtx)

fig, ax = plt.subplots(figsize=(20, 10))  # Set the figure size
# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()
# Out:
#              aluminium   ammonia   arsenic    barium   cadmium  chloramine  \
# aluminium     1.000000  0.064947  0.203322  0.289510 -0.120845    0.367590
# ammonia       0.064947  1.000000  0.054944  0.087933 -0.007289    0.115107
# arsenic       0.203322  0.054944  1.000000  0.365715  0.331366    0.348288
# barium        0.289510  0.087933  0.365715  1.000000 -0.037297    0.443206
# cadmium      -0.120845 -0.007289  0.331366 -0.037297  1.000000   -0.153186
# chloramine    0.367590  0.115107  0.348288  0.443206 -0.153186    1.000000
# chromium      0.344260  0.119367  0.303746  0.406946 -0.169112    0.556519
# copper        0.171429 -0.007646 -0.045766  0.053582 -0.108686    0.121022
# fluoride     -0.005470 -0.020277 -0.002053 -0.026582 -0.001030    0.005148
# bacteria     -0.086497  0.044964  0.049835  0.106641 -0.097619    0.148194
# viruses      -0.087601  0.098201  0.015507 -0.001022  0.011249   -0.012294
# ...

# %% [markdown]
# # Pruning Data

# %%
column_name = []
for columns in df.iloc[0:0]:
    print(df.iloc[0:0][columns])
    print(f'{columns =}')
    column_name.append(f'{columns }')

column_name = list(column_name)
print(column_name)
# Out:
# Series([], Name: aluminium, dtype: float64)
# columns ='aluminium'
# Series([], Name: ammonia, dtype: float64)
# columns ='ammonia'
# Series([], Name: arsenic, dtype: float64)
# columns ='arsenic'
# Series([], Name: barium, dtype: float64)
# columns ='barium'
# Series([], Name: cadmium, dtype: float64)
# columns ='cadmium'
# Series([], Name: chloramine, dtype: float64)
# columns ='chloramine'
# Series([], Name: chromium, dtype: float64)
# columns ='chromium'
# Series([], Name: copper, dtype: float64)
# columns ='copper'
# Series([], Name: fluoride, dtype: float64)
# columns ='fluoride'
# Series([], Name: bacteria, dtype: float64)
# columns ='bacteria'
# Series([], Name: viruses, dtype: float64)
# columns ='viruses'
# Series([], Name: lead, dtype: float64)
# columns ='lead'
# Series([], Name: nitrates, dtype: float64)
# columns ='nitrates'
# Series([], Name: nitrites, dtype: float64)
# columns ='nitrites'
# Series([], Name: mercury, dtype: float64)
# columns ='mercury'
# ...

# %%
column_name[0:20]
# Out:
# ['aluminium',
#  'ammonia',
#  'arsenic',
#  'barium',
#  'cadmium',
#  'chloramine',
#  'chromium',
#  'copper',
#  'fluoride',
#  'bacteria',
#  'viruses',
#  'lead',
#  'nitrates',
#  'nitrites',
#  'mercury',
#  'perchlorate',
#  'radium',
#  'selenium',
#  'silver',
#  'uranium']

# %%
corr_data = co_mtx[20:21]

# %%
corr_data
# Out:
#          aluminium   ammonia   arsenic    barium   cadmium  chloramine  \
# is_safe   0.352898 -0.017758 -0.121086  0.102858 -0.264755     0.20616
#
#          chromium    copper  fluoride  bacteria  ...      lead  nitrates  \
# is_safe  0.185814  0.049183  0.016932  -0.02262  ... -0.007048 -0.066662
#
#          nitrites   mercury  perchlorate    radium  selenium    silver  \
# is_safe  0.050487 -0.030407     0.083368  0.080389 -0.044926  0.105049
#
#           uranium  is_safe
# is_safe -0.071914      1.0
#
# [1 rows x 21 columns]

# %%
np.mean(co_mtx)
# Out:
# np.float64(0.11953756141235124)

# %%
#drop if correlation is negative for improving models
prun_data = []
for column in corr_data.columns:
    # print(column)
    # print(corr_data.iloc[0][column])
    if abs(corr_data.iloc[0][column])<0.10:
        prun_data.append(column)
prun_df = corr_data.drop(prun_data,axis=1)
print(prun_df)
# Out:
#          aluminium   arsenic    barium   cadmium  chloramine  chromium  \
# is_safe   0.352898 -0.121086  0.102858 -0.264755     0.20616  0.185814
#
#            silver  is_safe
# is_safe  0.105049      1.0

# %%
df = prun_df.head()
df.head()
# Out:
#          aluminium   arsenic    barium   cadmium  chloramine  chromium  \
# is_safe   0.352898 -0.121086  0.102858 -0.264755     0.20616  0.185814
#
#            silver  is_safe
# is_safe  0.105049      1.0

# %%
df = pd.read_excel(r'D:\M.eng\Machine learning\ML_project\WaterSafety_Data.xlsx')
df = pd.DataFrame(df)
X = df.iloc[:, 0:20]  # First 20 columns
y = df.iloc[:, 20]    # 21st column (index 20)
sns.jointplot(x=X.iloc[:, 0], y=y, data=df, kind='resid')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
df = pd.read_excel(r'D:\M.eng\Machine learning\ML_project\WaterSafety_Data.xlsx')

# Selecting X (first 20 columns) and Y (21st column)
X = df.iloc[:, 0:20]  # Features
y = df.iloc[:, 20]    # Target variable

# Add target variable to the dataset
df_plot = X.copy()
df_plot["Target"] = y  
# Create pairplot
sns.pairplot(df_plot, y_vars=["Target"], x_vars=df_plot.columns[:-1], kind="reg")
plt.show()

# %%
test = np.loadtxt('D:\M.eng\Machine learning\ML_project\Data\Water_Test_Data.txt')
x_test = test[:,0:21]
y_test = test[:,20]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\panda\AppData\Local\Temp\ipykernel_10144\859576275.py:1: SyntaxWarning: invalid escape sequence '\M'
#   test = np.loadtxt('D:\M.eng\Machine learning\ML_project\Data\Water_Test_Data.txt')

# %%
x_test
# Out:
# array([[2.720e+00, 2.681e+01, 1.000e-02, ..., 1.000e-02, 6.000e-02,
#         1.000e+00],
#        [3.130e+00, 9.420e+00, 6.000e-02, ..., 1.600e-01, 1.000e-02,
#         0.000e+00],
#        [5.000e-02, 2.838e+01, 4.000e-02, ..., 7.000e-02, 1.000e-02,
#         1.000e+00],
#        ...,
#        [5.000e-02, 2.213e+01, 8.000e-02, ..., 7.000e-02, 7.000e-02,
#         0.000e+00],
#        [2.000e-02, 7.880e+00, 3.000e-02, ..., 8.000e-02, 1.000e-02,
#         0.000e+00],
#        [2.710e+00, 2.752e+01, 1.000e-02, ..., 4.000e-01, 1.000e-02,
#         1.000e+00]], shape=(1600, 21))

# %%
y_test
# Out:
# array([1., 0., 1., ..., 0., 0., 1.], shape=(1600,))

# %%
sns.countplot(y_test)
plt.title('Categories')
# Out:
# Text(0.5, 1.0, 'Categories')
