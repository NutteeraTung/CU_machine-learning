# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import math
import json

# %%
ax = int(input("Enter number :"))
if ax%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
import json

x =  '{ "name":"John", "age":30, "city":"New York", "id":[2,5,85,94,103]}'
y = json.loads(x)
print(y["id"])
# Out:
# [2, 5, 85, 94, 103]

# %%
x =  { "name":"John", "age":30, "city":"New York", "id":[2,5,85,94,103]}
print("Keys" , x.keys())
print("Values" ,x.values())
# Out:
# Keys dict_keys(['name', 'age', 'city', 'id'])
# Values dict_values(['John', 30, 'New York', [2, 5, 85, 94, 103]])

# %%
x= np.random.rand(5)
y =np.random.rand(5)
plt.plot(x,y,'o:r',ms=20, mec='yellow',mfc='b') 
plt.title("title something", loc='left')
# Out:
# Text(0.0, 1.0, 'title something')
